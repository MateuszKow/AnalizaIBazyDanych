# %% [markdown]
# # Laboratorium 2

# %% [markdown]
# W ramach laboratorium 2 utworzono projekt zgodny z protokołem TIER i zasadami "tidy data". Przenalizowano w nim dane zebrane przez WHO na temat średniego spożycia różnych rodzajów alkoholu na osobę, w 193 różnych krajach na całym świecie w 2010 roku. Każdy z wymienionych trunków był w innych jednostkach: piwo w puszkach, wino w kieliszkach, wysokoprocentowe alkohole w kieliszkach, a czysty alkohol w litrach. Poniżej przedstawiono po piętnastu największych konsumentów każdego z rodzajów alkoholi w formie dataframe oraz wykresów słupkowych .

# %% [markdown]
# ### Najwięksi konsumenci piwa na świecie.

# %%
from IPython import display
import pandas as pd

# %%
beer=pd.read_csv("../Analysis Data/top_beer_consumers.csv")
beer.index=[x for x in range(1,16)]
beer
# Out:
#            Country  consumed cans of beer per-capita
# 1          Namibia                               376
# 2   Czech Republic                               361
# 3            Gabon                               347
# 4          Germany                               346
# 5        Lithuania                               343
# 6           Poland                               343
# 7        Venezuela                               333
# 8          Ireland                               313
# 9            Palau                               306
# 10         Romania                               297
# 11         Belgium                               295
# 12          Panama                               285
# 13           Spain                               284
# 14          Serbia                               283
# 15          Latvia                               281

# %%
display.Image("../Analysis Data/top_beer_consumers.jpg")

# %% [markdown]
# ### Najwięksi konsumenci wina na świecie.

# %%
wine=pd.read_csv("../Analysis Data/top_wine_consumers.csv")
wine.index=[x for x in range(1,16)]
wine
# Out:
#               Country  consumed glasses of wine per-capita
# 1              France                                  370
# 2            Portugal                                  339
# 3             Andorra                                  312
# 4         Switzerland                                  280
# 5             Denmark                                  278
# 6            Slovenia                                  276
# 7          Luxembourg                                  271
# 8             Croatia                                  254
# 9               Italy                                  237
# 10  Equatorial Guinea                                  233
# 11          Argentina                                  221
# 12            Uruguay                                  220
# 13             Greece                                  218
# 14          Australia                                  212
# 15            Belgium                                  212

# %%
display.Image("../Analysis Data/top_wine_consumers.jpg")

# %% [markdown]
# ### Najwięksi konsumenci alkoholi wysokoprocentowych na świecie.

# %%
spirits=pd.read_csv("../Analysis Data/top_spirits_consumers.csv")
spirits.index=[x for x in range(1,16)]
spirits
# Out:
#                Country  consumed shots of spirits per-capita
# 1              Grenada                                   438
# 2              Belarus                                   373
# 3                Haiti                                   326
# 4   Russian Federation                                   326
# 5            St. Lucia                                   315
# 6               Guyana                                   302
# 7             Slovakia                                   293
# 8             Dominica                                   286
# 9             Thailand                                   258
# 10        Cook Islands                                   254
# 11            Bulgaria                                   252
# 12          Kazakhstan                                   246
# 13           Lithuania                                   244
# 14             Ukraine                                   237
# ...

# %%
display.Image("../Analysis Data/top_spirits_consumers.jpg")

# %% [markdown]
# ### Najwięksi konsumenci czystego alkoholu na świecie.

# %%
alcohol=pd.read_csv("../Analysis Data/top_alcohol_consumers.csv")
alcohol.index=[x for x in range(1,16)]
alcohol
# Out:
#                Country  consumed litres of pure alcohol per-capita
# 1              Belarus                                        14.4
# 2            Lithuania                                        12.9
# 3              Andorra                                        12.4
# 4              Grenada                                        11.9
# 5       Czech Republic                                        11.8
# 6               France                                        11.8
# 7   Russian Federation                                        11.5
# 8              Ireland                                        11.4
# 9             Slovakia                                        11.4
# 10          Luxembourg                                        11.4
# 11             Germany                                        11.3
# 12             Hungary                                        11.3
# 13            Portugal                                        11.0
# ...

# %%
display.Image("../Analysis Data/top_alcohol_consumers.jpg")

# %% [markdown]
# Mateusz Kowalski <br> grupa: piątek 9:15 <br> numer indeksu 401939
